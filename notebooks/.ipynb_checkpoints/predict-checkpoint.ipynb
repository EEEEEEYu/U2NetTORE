# %%
import os
import sys
import glob
import torch
import platform

import os.path as op
import numpy as np
from matplotlib import pyplot as plt

sys.path.append('..')
from scripts.data import DataInterface
from scripts.model import ModelInteface
from scripts.utils import ntore_to_redgreen, gen_tore_plus

# %load_ext autoreload
# %autoreload 2

# %%
print('Current Directory: ', os.getcwd())
print('Current Node: ', platform.node())
print('Cuda availability: ', torch.cuda.is_available())
# Out:
# Current Directory:  /mnt/nfs/scratch1/zhongyangzha/DVS_HPE/U2NetTORE/notebooks
# Current Node:  node185
# Cuda availability:  True

# %%
def get_model_path(date, root='/mnt/nfs/scratch1/zhongyangzha/DVS_HPE/U2NetTORE/lightning_logs', best=True):
    model_subdir = op.join(root, date, 'checkpoints')
    if best:
        model_path = glob.glob(op.join(model_subdir, 'best*'))[0]
    else:
        model_path = op.join(model_subdir, 'last.ckpt')
    return model_path

# %%
data = DataInterface(num_workers=1, dataset='mask_dataset', batch_size=1, 
                     tore_dir="/mnt/nfs/work1/trahman/zhongyangzha/dvs_hpe/ntore_dataset/synthetic", 
                     mask_dir='/mnt/nfs/work1/trahman/zhongyangzha/dvs_hpe/ntore_dataset/masks_acc', 
                     percentile=90, seq_len=16, acc_time=0.02, step_size=0.02, 
                     cache_size=1, base_number=128, test_characters=['Miku'], accumulated=True)
# Initiate train/val/test set and loaders
data.setup()
# Out:
# MaskDataset
# From Data interface: 1
# running dataset setup...
# [√] Using pre-accumulated mask files.
# ===== READER NUM: 448 =======
# Train and Val indexes shape:  (1318896, 2)
# ===== READER NUM: 64 =======
# Test indexes shape:  (188416, 2)
# Length of train data: 1055120
# Length of val data:  263776

# %%
device = 'cuda'

# No ConvLSTM
model_path = get_model_path('03-26-09-44')
# ConvLSTM used
# model_path = get_model_path('03-25-21-46')

model = ModelInteface.load_from_checkpoint(model_path)
model = model.to(device)
print('ConvLSTM used: ', model.model.use_convlstm)
# Out:
# Model hparams saved!
# ConvLSTM used:  False

# %%
model.model.use_convlstm
# Out:
# False

# %%
# Using data from loader
idx = 2000
batch = data.testset[idx]
ntores, masks = batch
# ntores = ntores.to('cuda')
res = model.predict_step(batch[0].to(device), idx)
del batch

# %%
inbatch_idx = 9
res_binary = np.where(res.cpu().detach().numpy()[inbatch_idx]>0.1,1,0)
combined_ntore = ntore_to_redgreen(ntores.cpu().detach().numpy()[inbatch_idx]).transpose(0,2,3,1)
# res_binary = np.where(res.numpy()>0.1,1,0)[idx]
plt.figure()
plt.imshow(torch.sigmoid(res[inbatch_idx]).cpu().detach().numpy())
plt.axis('off')
plt.figure()
plt.imshow(res_binary)
plt.axis('off')
plt.figure()
plt.imshow(masks[inbatch_idx])
plt.axis('off')
plt.figure()
plt.imshow(combined_ntore[0])
plt.axis('off')
plt.figure()
plt.imshow(combined_ntore[1])
plt.axis('off')
plt.figure()
plt.imshow(combined_ntore[2])
plt.axis('off')

# plt.imshow(ntores[inbatch_idx][0].cpu().detach().numpy())
# plt.figure()
# plt.imshow(ntores[inbatch_idx][4].cpu().detach().numpy())
# plt.figure()
# plt.imshow(ntores[inbatch_idx][1].cpu().detach().numpy())
# plt.figure()
# plt.imshow(ntores[inbatch_idx][5].cpu().detach().numpy())
# Out:
# (-0.5, 345.5, 259.5, -0.5)

# %%
combined_ntore.shape
# Out:
# (4, 3, 260, 346)
